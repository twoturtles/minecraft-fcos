# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from pathlib import Path

import tt

LOG = logging.getLogger(__name__)
tt.logging_init()

# %%
CATEGORIES = [
    "chicken",
    "cow",
    "creeper",
    "enderman",
    "pig",
    "sheep",
    "skeleton",
    "spider",
    "villager",
    "zombie",
]
CATEGORIES.sort()

mobs_path = Path.home() / "src/data/mobs1"
images_path = mobs_path / "640"

# %%
bbe = tt.BBoxEdit.load(mobs_path / "results2.json")
bbe.display()
# Out:
# ...
# 'DO SUBMIT 8'
# [BBox(category='sheep', xyxyn=[0.289, 0.468, 0.356, 0.577]),
#  BBox(category='spider', xyxyn=[0.539, 0.32, 0.629, 0.406]),
#  BBox(category='chicken', xyxyn=[0.518, 0.389, 0.554, 0.444]),
#  BBox(category='pig', xyxyn=[0.606, 0.32, 0.644, 0.362])]
# [{'x': 184.95999999999998,
#   'y': 299.52000000000004,
#   'width': 42.879999999999995,
#   'height': 69.75999999999993,
#   'label': 'sheep'},
#  {'x': 349, 'y': 218, 'width': 63, 'height': 43, 'label': 'spider'},
#  {'x': 331.52,
#   'y': 248.96,
#   'width': 23.040000000000077,
#   'height': 35.20000000000002,
#   'label': 'chicken'},
#  {'x': 387.84,
#   'y': 204.8,
#   'width': 24.160000000000025,
#   'height': 19.19999999999999,
#   'label': 'pig'}]
# [BBox(category='sheep', xyxyn=[0.289, 0.4680000000000001, 0.356, 0.577]),
#  BBox(category='spider', xyxyn=[0.5453125, 0.340625, 0.64375, 0.4078125]),
#  BBox(category='chicken', xyxyn=[0.518, 0.389, 0.554, 0.44400000000000006]),
# ...

# %%
bbe.save(mobs_path / "results2.json")
