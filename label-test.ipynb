# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from pathlib import Path

import tt

LOG = logging.getLogger(__name__)
tt.logging_init()

# %%
CATEGORIES = [
    "chicken",
    "cow",
    "creeper",
    "enderman",
    "pig",
    "sheep",
    "skeleton",
    "spider",
    "villager",
    "zombie",
]
CATEGORIES.sort()

mobs_path = Path.home() / "src/data/mobs1"
images_path = mobs_path / "640"

# %%
dset = tt.Dataset.load(mobs_path / "result1.json")
bbe = tt.BBoxEdit(dset)
bbe.display()
# Out:
# VBox(children=(IntSlider(value=0, continuous_update=False, description='Index:', max=44), HBox(children=(Butto…
# 'DO SUBMIT 0'
# [BBox(category='sheep', xyxyn=[0.249, 0.167, 0.554, 0.533])]
# [{'x': 159.36,
#   'y': 106.88000000000001,
#   'width': 195.20000000000005,
#   'height': 234.24,
#   'label': 'sheep'}]
# [BBox(category='sheep', xyxyn=[0.24900000000000003, 0.167, 0.554, 0.533])]
# 'DO SUBMIT 1'
# [BBox(category='cow', xyxyn=[0.59, 0.392, 0.636, 0.435]),
#  BBox(category='pig', xyxyn=[0.0, 0.48, 0.298, 0.7])]
# [{'x': 377.59999999999997,
#   'y': 250.88,
#   'width': 29.440000000000055,
#   'height': 27.519999999999982,
#   'label': 'cow'},
#  {'x': 0, 'y': 307.2, 'width': 197, 'height': 153.8, 'label': 'pig'}]
# [BBox(category='cow', xyxyn=[0.59, 0.392, 0.636, 0.43499999999999994]),
#  BBox(category='pig', xyxyn=[0.0, 0.48, 0.3078125, 0.7203125])]
# 'DO SUBMIT 2'
# [BBox(category='sheep', xyxyn=[0.404, 0.45, 0.512, 0.642]),
#  BBox(category='pig', xyxyn=[0.314, 0.472, 0.404, 0.577])]
# [{'x': 258.56, 'y': 288, 'width': 83.44, 'height': 129, 'label': 'sheep'},
#  {'x': 200.96,
#   'y': 302.08,
#   'width': 62.03999999999999,
#   'height': 76.92000000000002,
#   'label': 'pig'}]
# [BBox(category='sheep', xyxyn=[0.404, 0.45, 0.534375, 0.6515625]),
#  BBox(category='pig', xyxyn=[0.314, 0.472, 0.4109375, 0.5921875])]

# %%
xyxyn=[0.249, 0.167, 0.554, 0.533]
size = (1000, 1000)
size = (640, 640)

xyxy = tt.xyxyn_to_xyxy(xyxyn, size)
coco = tt.xyxyn_to_coco(xyxyn, size)
xyxyn2 = tt.xyxy_to_xyxyn(xyxy, size)
xyxyn3 = tt.coco_to_xyxyn(tt.xyxyn_to_coco(xyxyn, size), size)
xyxyn4 = tt.xyxy_to_xyxyn(tt.xyxyn_to_xyxy(xyxyn, size), size)

print(xyxyn)
print(xyxy)
print(coco)
print(xyxyn2)
print(xyxyn3)
print(xyxyn4)
# Out:
# [0.249, 0.167, 0.554, 0.533]
# [159, 106, 354, 341]
# [159, 106, 195, 235]
# [0.2484375, 0.165625, 0.553125, 0.5328125]
# [0.2484375, 0.165625, 0.553125, 0.5328125]
# [0.2484375, 0.165625, 0.553125, 0.5328125]

# %%
xyxyn=[0.249, 0.167, 0.554, 0.533]
size = (1000, 1000)
size = (640, 640)

xyxy = tt.xyxyn_to_xyxy(xyxyn, size)
coco = tt.xyxyn_to_coco(xyxyn, size)
xyxyn2 = tt.xyxy_to_xyxyn(xyxy, size)
xyxyn3 = tt.coco_to_xyxyn(tt.xyxyn_to_coco(xyxyn, size), size)
xyxyn4 = tt.xyxy_to_xyxyn(tt.xyxyn_to_xyxy(xyxyn, size), size)

print(xyxyn)
print(xyxy)
print(coco)
print(xyxyn2)
print(xyxyn3)
print(xyxyn4)
# Out:
# [0.249, 0.167, 0.554, 0.533]
# [159.36, 106.88000000000001, 354.56000000000006, 341.12]
# [159.36, 106.88000000000001, 195.20000000000005, 234.24]
# [0.24900000000000003, 0.167, 0.554, 0.533]
# [0.24900000000000003, 0.167, 0.554, 0.533]
# [0.24900000000000003, 0.167, 0.554, 0.533]
