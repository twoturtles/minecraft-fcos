# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from pathlib import Path

import tt

LOG = logging.getLogger(__name__)
tt.logging_init()

# %%
CATEGORIES = [
    "chicken",
    "cow",
    "creeper",
    "enderman",
    "pig",
    "sheep",
    "skeleton",
    "spider",
    "zombie",
]
CATEGORIES.sort()

mobs_path = Path.home() / "src/data/mobs2"
images_path = mobs_path / "640"

# %%
bbe = tt.BBoxEdit(mobs_path / "luke_results.json")
bbe.display()

# %%
import pandas as pd
import numpy as np
from ipydatagrid import DataGrid, TextRenderer, BarRenderer, Expr
from ipywidgets import VBox, HBox, Button, Output

# %%
# Create sample data
df = pd.DataFrame(
    {
        "name": ["Alice", "Bob", "Charlie", "Diana", "Eve"],
        "age": [25, 30, 35, 28, 42],
        "city": ["New York", "Paris", "London", "Tokyo", "Berlin"],
        "salary": [75000, 85000, 95000, 72000, 105000],
    }
)

# Basic grid
grid = DataGrid(df)
display(grid)
# Out:
# DataGrid(auto_fit_params={'area': 'all', 'padding': 30, 'numCols': None}, corner_renderer=None, default_render…
