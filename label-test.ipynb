# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from pathlib import Path


import tt

LOG = logging.getLogger(__name__)
tt.logging_init()

# %%
CATEGORIES = [
    "chicken",
    "cow",
    "creeper",
    "enderman",
    "pig",
    "sheep",
    "skeleton",
    "spider",
    "villager",
    "zombie",
    "test1",
    "test2",
    "zzzz",
]
CATEGORIES.sort()

mobs_path = Path.home() / "src/data/mobs1"
images_path = mobs_path / "640"

# %%
files = sorted(list(images_path.glob("*.png")))
annotations = {}
annotations_path = mobs_path / 'bbw.json'

# %%
dset = tt.Dataset.load(mobs_path / "result1.json")
tt.BBoxEdit(dset)
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 dset = tt.Dataset.load(mobs_path / "result1.json")
# ----> 2 tt.BBoxEdit(dset)
#
# File <string>:9, in __init__(self, dset)
#
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/jupyter_bbox_widget/bbox.py:72, in BBoxWidget.__init__(self, **kwargs)
#      71 def __init__(self, **kwargs):
# ---> 72     super().__init__(**kwargs)
#      73     self.on_msg(self._handle_custom_msg)
#      74     self.submit_callback = None
#
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/anywidget/widget.py:62, in AnyWidget.__init__(self, *args, **kwargs)
#      57 anywidget_traits[_ANYWIDGET_ID_KEY] = t.Unicode(
#      58     f"{self.__class__.__module__}.{self.__class__.__name__}",
#      59 ).tag(sync=True)
#      61 self.add_traits(**anywidget_traits)
# ---> 62 super().__init__(*args, **kwargs)
#      63 _register_anywidget_commands(self)
#
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/ipywidgets/widgets/widget.py:503, in Widget.__init__(self, **kwargs)
#     501 """Public constructor"""
#     502 self._model_id = kwargs.pop('model_id', None)
# --> 503 super().__init__(**kwargs)
#     505 Widget._call_widget_constructed(self)
#     506 self.open()
#
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/traitlets/traitlets.py:1355, in HasTraits.__init__(self, *args, **kwargs)
#    1353 for key, value in kwargs.items():
#    1354     if self.has_trait(key):
# -> 1355         setattr(self, key, value)
#    1356         changes[key] = Bunch(
#    1357             name=key,
#    1358             old=None,
#    (...)   1361             type="change",
#    1362         )
#    1363     else:
#    1364         # passthrough args that don't set traits to super
#
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/traitlets/traitlets.py:3635, in List.set(self, obj, value)
#    3633     return super().set(obj, [value])  # type:ignore[list-item]
#    3634 else:
# -> 3635     return super().set(obj, value)
#
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/traitlets/traitlets.py:690, in TraitType.set(self, obj, value)
#     689 def set(self, obj: HasTraits, value: S) -> None:
# --> 690     new_value = self._validate(obj, value)
#     691     assert self.name is not None
#     692     try:
#
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/traitlets/traitlets.py:722, in TraitType._validate(self, obj, value)
#     720     return value
#     721 if hasattr(self, "validate"):
# --> 722     value = self.validate(obj, value)
#     723 if obj._cross_validation_lock is False:
#     724     value = self._cross_validate(obj, value)
#
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/traitlets/traitlets.py:3478, in Container.validate(self, obj, value)
#    3476     assert self.klass is not None
#    3477     value = self.klass(value)  # type:ignore[call-arg]
# -> 3478 value = super().validate(obj, value)
#    3479 if value is None:
#    3480     return value
#
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/traitlets/traitlets.py:2311, in Instance.validate(self, obj, value)
#    2309     return t.cast(T, value)
#    2310 else:
# -> 2311     self.error(obj, value)
#
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/traitlets/traitlets.py:831, in TraitType.error(self, obj, value, error, info)
#     825 else:
#     826     e = "The '{}' trait expected {}, not {}.".format(
#     827         self.name,
#     828         info or self.info(),
#     829         describe("the", value),
#     830     )
# --> 831 raise TraitError(e)
#
# TraitError: The 'colors' trait of a BBoxWidget instance expected a list, not the Colors at '0x1156a2120'.
