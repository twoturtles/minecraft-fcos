# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from pathlib import Path

import tt

LOG = logging.getLogger(__name__)
tt.logging_init()

# %%
CATEGORIES = [
    "chicken",
    "cow",
    "creeper",
    "enderman",
    "pig",
    "sheep",
    "skeleton",
    "spider",
    "villager",
    "zombie",
]
CATEGORIES.sort()

mobs_path = Path.home() / "src/data/mobs1"
images_path = mobs_path / "640"

# %%
bbe = tt.BBoxEdit(mobs_path / "results2.json")
bbe.display()

# %%
bbe = tt.BBoxEdit(mobs_path / "results2.json")
bbe.display()
