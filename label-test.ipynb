# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from pathlib import Path

from PIL import Image

import tt

LOG = logging.getLogger(__name__)
tt.logging_init()

# %%
CATEGORIES = [
    "chicken",
    "cow",
    "creeper",
    "enderman",
    "pig",
    "sheep",
    "skeleton",
    "spider",
    "villager",
    "zombie",
]
CATEGORIES.sort()

mobs_path = Path.home() / "src/data/mobs1"
images_path = mobs_path / "640"

# %%
dset = tt.Dataset.load(mobs_path / "result1.json")
bbe = tt.BBoxEdit(dset)
bbe.display()
# Out:
# VBox(children=(IntSlider(value=0, continuous_update=False, description='Index:', max=44), HBox(children=(Butto…
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/src/mc_exp/.venv/lib/python3.13/site-packages/ipywidgets/widgets/widget_output.py:5, in _on_submit(self, button)
#       1 # Copyright (c) Jupyter Development Team.
#       2 # Distributed under the terms of the Modified BSD License.
#       4 """Output class.
# ----> 5
#       6 Represents a widget that can be used to display output within the widget area.
#       7 """
#       9 import sys
#      10 from functools import wraps
#
# NameError: name 'Image' is not defined

# %%
ifile = list(images_path.glob("*.png"))[0]
img = Image.open(ifile)
img.size
