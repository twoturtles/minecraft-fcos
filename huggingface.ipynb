# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import random
from pathlib import Path
from typing import Any

import datasets
import torch
import torchvision as tv
from torch.utils.data.dataloader import DataLoader
from torchvision.transforms import v2 as transforms

import bb
import tt

LOG = logging.getLogger(__name__)
tt.logging_init()

# %%
data_path = Path.home() / "src/data"
mc_data_path = data_path / "minecraft/info.json"
dset = bb.Dataset.load(mc_data_path)
hf_root = data_path / "hf"
torch_root = data_path / "torchvision"

# %%
dset = bb.Dataset.load(mc_data_path)
dset.to_hf_imagefolder(hf_root / "minecraft")
# Out:
# [20:22:56]:[INFO]:(bb): Exported 408 images to ImageFolder format at /Users/joe/src/data/hf/minecraft

# %%
from datasets import load_dataset
ds = load_dataset("imagefolder", data_dir=hf_root / "minecraft")
# Out:
# Resolving data files:   0%|          | 0/409 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/409 [00:00<?, ?files/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
ds["train"]["image"]
# Out:
# Column([<PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x640 at 0x13AF4E210>, <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x640 at 0x13AF4D5B0>, <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x640 at 0x13AF4E570>, <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x640 at 0x13AF4E450>, <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x640 at 0x13AF4E330>, ...])

# %%
dset = bb.Dataset.load(mc_data_path)
dset.to_coco(data_path / "coco/minecraft")
# Out:
# [21:28:08]:[INFO]:(bb): Exported 408 images to COCO format at /Users/joe/src/data/coco/minecraft
